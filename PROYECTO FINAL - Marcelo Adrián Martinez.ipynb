# %% [markdown]
# # **CURSO: DATA SCIENCE - CODERHOUSE**
# ### **AUTOR:** MARCELO ADRIÁN MARTINEZ

# %% [markdown]
# ![Clinica.png](data:image/png;base64,...)

# %% [markdown]
# #### **ABSTRACTO**
#
# El presente informe está destinado a los responsables de la gestión de la Clínica Tiempo la cual cuenta con una larga trayectoria en la ciudad, siendo la más prestigiosa de la región.
# Ante la situación de la limitación de recursos con los que cuenta la clínica y con el fin de prever una compra de insumos y otros elementos de trabajo, los ejecutivos están buscando conocer cuál será la duración de la estancia de los pacientes en el clínica.
# Para ello, el director de la clínica nos facilita este dataset con datos recopilados sobre distintas cuestiones de los pacientes que han estado en la clínica.
# Los campos del dataset se refieren a distintos aspectos registrados de cada paciente.
# En base a ello y a las necesidades de información de los directivos, se realizará un modelo predictivo con el fin de establecer la duración de la estancia de los pacientes en la Clínica.

# %% [markdown]
# #### **OBJETIVOS**
#
# * Establecer los tiempos de duración de estadía de los pacientes que presentan mayor moda.
# *   Determinar los factores inciden en mayor medida en la duración de la estancia de los pacientes en la
# clínica.
# * Analizar la asignación de recursos en pos de ofrecer un excelente servicio.
# * Identificar características que permitan agrupar a los pacientes según sus necesidades.

# %% [markdown]
# #### **CONTEXTO COMERCIAL**
# La Clínica tiene una amplia trayectoria en la ciudad, brindando servicios de excelencia a sus miles de
# pacientes que año tras año llegan a la misma. Esto la ha posicionado entre los demás centros de salud de
# la zona, tanto por su prestaciones de excelencia como también su constante inversión en equipos de alta
# tecnología.
# La Clínica ofrece distintos servicios, entre ellos están los de internación por diversas cuestiones de
# salud.
# En el último año la clínica tuvo 100.000 internaciones y la duración de dichas internaciones van
# de 1 (uno) a 17 (diecisiete) días.

# %% [markdown]
# #### **PROBLEMA COMERCIAL**
# En base a lo mencionado en los apartados anteriores el director de la Clínica, en pos de seguir ofreciendo
# a sus pacientes la mejor atención, quiere determinar la cantidad y la duración de las estancias de los
# pacientes con el fin de realizar una óptima asignación de los recursos con los que cuenta la Clínica.
#
# #### **PREGUNTAS**
#     * ¿Cuántos días van a durar las estancias de los pacientes en la clínica?
#     * ¿Cuál es la duración máxima de la estancia? ¿Y la mínima?
#     * ¿Qué factores inciden en mayor medida en la duración de la estancia?
#     * ¿Cuál será la cantidad de pacientes admitidos?
#     * ¿Existe alguna relación entre el género del paciente y la duración de la estancia?
# #### **HIPÓTESIS**
#     - Las enfermedades que afectan a los sistemas digestivos, circulatorios o respiratorio inciden en mayor medida en la duración de la estancia del paciente en la clínica.

# %% [markdown]
# #### **CONTEXTO ANALÍTICO**
# Para cumplir con los objetivos planteados y dar solución a la problemática, el director de la clínica nos facilita este dataset con datos recopilados sobre distintas cuestiones de los pacientes que han estado en la clínica. El mismo está estructurado en 28 columnas y 100.000 filas.
# Los campos del dataset se refieren a distintos aspectos registrados de cada paciente, entre las variables están:
# *   ID Admisión: un identificador por cada admisión de un paciente que se da en el hospital.
# *   FechaVisita: la fecha en la que se produjo la visita del paciente.
# *   NumReadmisiones: el número de readmisiones que se han dado.
# *   Género: 1 para mujeres y 0 para hombres.
# *   Renal: si tiene algún síntoma o problema de índole renal.
# *   Asma: si tiene algún síntoma o problema de asma.
# *   FaltaHierro: si tiene algún problema de falta de hierro o no.
# *   Neumonia: si tiene algún problema de neumonía o no.
# *   DependenciaSustancias: si tiene algún problema de dependencia de sustancias o no.
# *   DesordenPsicologico: si tiene algún problema de desórdenes psicológicos o no.
# *   Depresion: si tiene algún problema de depresión o no.
# *   OtrosDesordenesPsiquicos: si tiene algún problema de otros desórdenes psíquicos o no.
# *   Fibrosis: si tiene algún problema de fibrosis o no.
# *   Malnutricion: si tiene algún problema de malnutrición o no.
# *   DesordenSangre: si tiene algún problema de desorden en sangre o no.
# *   Sodio: si tiene algún síntoma o problema de sodio.
# *   Hematocrito: si tiene algún síntoma o problema de hematocrito.
# *   Neutrofilos: si tiene algún síntoma o problema de neutrófilos.
# *   Glucosa: si tiene algún síntoma o problema de glucosa.
# *   UreaSangre: si tiene algún síntoma o problema de urea en sangre.
# *   Creatinina: si tiene algún síntoma o problema de creatinina.
# *   BMI: el índice de masa corporal del paciente.
# *   Pulso: pulsaciones del paciente por minuto.
# *   Respiracion: la respiración del paciente cada 30 segundos.
# *   DiagnosticoSecundario: cuál es el diagnóstico secundario del paciente.
# *   FechaAlta: la fecha en la que se le ha dado de alta al paciente.
# *   IDHospital: el identificar de la sede del hospital donde ha sido ingresado.
# *   DuracionEstancia: los días que duró la estancia del paciente en la clínica.

# %% [markdown]
# ## **IMPORTACIÓN DE LOS PAQUETES**

# %% [markdown]
# Se importan las librerías a utilizarse en el proyecto:

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import xgboost as xgb
from google.colab import files
from PIL  import Image
import requests
import missingno as msno
import json
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn.model_selection import LeaveOneOut
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree
from sklearn.tree import plot_tree
from sklearn.tree import export_graphviz
from sklearn.tree import export_text
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn.metrics import make_scorer
from sklearn import metrics
from sklearn.metrics import mean_absolute_error as MAE
from sklearn.metrics import r2_score
from sklearn.model_selection import  learning_curve
from sklearn import svm
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.metrics import precision_score, recall_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# ## **CARGA DEL DATASET "CLINICA"**

# %%
from posixpath import sep
url= "https://raw.githubusercontent.com/Marcelo-A-Martinez/DATASET_CLINICA/main/Clinica.csv"
Clinica= pd.read_csv(url, sep=';', decimal= ".", header=0)
Clinica.head()
# Out:
#    idAdmision fechaVisita  numReadmisiones  genero  renal  asma  faltaHierro  \
# 0           1   8/29/2012              0.0       1      0     0            0
# 1           3   9/22/2012              1.0       1      0     0            0
# 2           4    8/9/2012              0.0       1      0     0            0
# 3           5  12/20/2012              0.0       1      0     0            0
# 4           6  11/27/2012              3.0       0      0     0            0
#
#    neumonia  dependenciaSustancias  desordenPsicologico  ...     glucosa  \
# 0         0                      0                    0  ...  192.476918
# 1         0                      0                    0  ...  130.530524
# 2         0                      0                    0  ...  163.377028
# 3         1                      0                    1  ...   94.886654
# 4         0                      0                    0  ...  120.265259
#
#    ureaSangre  creatinina        bmi  pulso  respiracion  \
# ...

# %% [markdown]
# ## **ANÁLISIS DEL CONJUNTO DE DATOS**

# %% [markdown]
# #### **ANÁLISIS DE CORRELACIÓN**

# %% [markdown]
# Análisis de varibles con mayor correlación respecto a la variable objetivo "duraciónEstancia":

# %%
cor=Clinica.corr()
cortarget=abs(cor["duracionEstancia"])
Var_Destacadas= cortarget[cortarget>=0.20]
print(Var_Destacadas)
# Out:
# <ipython-input-3-08e9561022e0>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor=Clinica.corr()
# numReadmisiones             0.692680
# faltaHierro                 0.214208
# desordenPsicologico         0.315288
# otrosDesordenesPsiquicos    0.209112
# desordenSangre              0.240024
# duracionEstancia            1.000000
# Name: duracionEstancia, dtype: float64

# %% [markdown]
# Llevado adelante el análisis de correlatividad, se determinó que existen 4 variables que tienen mayor grado de correlación con respecto a la variable objetivo "duraciónEstancia".

# %% [markdown]
# #### **ELIMINACIÓN DE VARIABLES**

# %% [markdown]
# Se procede a eliminar aquellas variables que no presentan una correlación alta respecto a la variable objetivo, dejando solamente aquellas que si lo presentan.

# %%
Clinica1= Clinica.drop(['idAdmision','fechaVisita', 'fechaAlta', 'idHospital' , 'asma', 'neumonia' ,
'dependenciaSustancias' , 'depresion' , 'fibrosis' , 'hematocrito' , 'neutrofilos', 'sodio' , 'glucosa' , 'ureaSangre' ,
'creatinina' , 'bmi' , 'pulso' , 'respiracion' , 'diagnosticoSecundario' , 'renal' , 'genero', 'malnutricion'], axis=1)

# %% [markdown]
# #### **PRINCIPALES ESTADÍSTICAS**

# %%
Clinica1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95013 entries, 0 to 95012
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   numReadmisiones           95013 non-null  float64
#  1   faltaHierro               95013 non-null  int64
#  2   desordenPsicologico       95013 non-null  int64
#  3   otrosDesordenesPsiquicos  95013 non-null  int64
#  4   desordenSangre            95013 non-null  int64
#  5   duracionEstancia          95013 non-null  int64
# dtypes: float64(1), int64(5)
# memory usage: 4.3 MB

# %%
Clinica1.describe( )
# Out:
#        numReadmisiones   faltaHierro  desordenPsicologico  \
# count     95013.000000  95013.000000         95013.000000
# mean          0.914464      0.095092             0.239062
# std           1.293546      0.293344             0.426513
# min           0.000000      0.000000             0.000000
# 25%           0.000000      0.000000             0.000000
# 50%           0.000000      0.000000             0.000000
# 75%           2.000000      0.000000             0.000000
# max           4.000000      1.000000             1.000000
#
#        otrosDesordenesPsiquicos  desordenSangre  duracionEstancia
# count              95013.000000    95013.000000       95013.00000
# mean                   0.049330        0.080168           3.77601
# std                    0.216557        0.271555           2.18028
# min                    0.000000        0.000000           1.00000
# 25%                    0.000000        0.000000           2.00000
# ...

# %% [markdown]
# En la tabla anterior se pueden observar las principales estadísticas del nuevo dataset conformado por la variable objetivo y las demás variables que presentan un grado de correlación más alta respecto a la primera.
# Se puede extraer que en el caso de la duración de la Estancia, el mismo presenta un mínimo de 1 día y un máximo de 17 días; con una media de 4 días y un desvío estándar de 2,18 días.
# En el caso del número de readmisiones, se puede establecer que el mínimo es 0 (cero, por ende no reingresaron nuevamente a la clínica) y el máximo es 4 (cuatro); por otro lado la media arroja que es de aproximadamente 1 con un desvío estándar de 1,29 días.
# En el caso de las demás variables, al ser de tipo binaria, el mínimo siempre será 0 (cero) y el máximo 1 (uno).
# En cuanto a la variable **falta de hierro**, tiene una media de 0,095 y un desvío estándar de 0,29. **Desorden Psicológico**, tiene una media de 0,24 y un desvío estándar de 0,42. En el caso de **otros desórdenes psíquicos**,su media es de 0,049 y un desvío estandar de 0,22. Y la variable **desorden en sangre**, presenta una media de 0,08 y un desvío estándar de 0,27.

# %% [markdown]
# ### **VISUALIZACIÓN DE PRINCIPALES VARIABLES**

# %% [markdown]
# **Gráfico 1: Cantidad de pacientes según la duración de la estadía**

# %% [markdown]
# Otro aspecto relevante y que se vincula con uno de los objetivos que se plantean, se basa en cuál es la cantidad de pacientes agrupados en función de la cantidad de días que permanecieron en la clínica.

# %%
CANTIDAD_PACIENTES_ESTADIA = Clinica1.groupby(['duracionEstancia']).size().reset_index(name='Cantidad_Pacientes').head(10)

fig, ax = plt.subplots(figsize=(8,4))
plt.xticks(range(18))
ax.bar(CANTIDAD_PACIENTES_ESTADIA['duracionEstancia'], CANTIDAD_PACIENTES_ESTADIA.Cantidad_Pacientes)
ax.set_title('Gráfico 1: Cantidad de pacientes según la duración de la estadía')
ax.set_ylabel('Cantidad de Pacientes')
ax.set_xlabel('Duración de la Estadía (en días)')
# Out:
# Text(0.5, 0, 'Duración de la Estadía (en días)')

# %% [markdown]
# **Interpretación**
#
# En primera instancia, un dato interesante que se puede extraer del conjunto está vinculado con el número de pacientes de acuerdo al tiempo que estuvieron internados en la clínica. A partir del gráfico 1, se puede observar que existe una mayor cantidad de pacientes que permanecen en la clínica 1, 3 y 4 días.

# %% [markdown]
# **Gráfico 2: Cantidad de veces que fueron readmitidos los pacientes**

# %%
CANTIDAD_READMISIONES = Clinica1.groupby(['numReadmisiones']).size().reset_index(name='Cantidad_Readmisiones')

fig, ax = plt.subplots(figsize=(8,4))
plt.xticks(range(18))
ax.bar(CANTIDAD_READMISIONES['numReadmisiones'], CANTIDAD_READMISIONES.Cantidad_Readmisiones)
ax.set_title('Gráfico 2: Cantidad pacientes agrupados según el número de readmisiones')
ax.set_ylabel('Cantidad de Pacientes')
ax.set_xlabel('Cantidad de Readmisiones')
# Out:
# Text(0.5, 0, 'Cantidad de Readmisiones')

# %% [markdown]
# **Interpretación**
#
# Otro dato interesante está relacionado con el número de readmisiones de los pacientes, el cual se refiere a la cantidad de veces que volvió a ingresar a la clínica. De ello se desprende que, el 57,92% de los pacientes no tuvieron readmisiones; en tanto que el 15,79% fue readmitido al menos una vez; el 10,51% fue reamitido dos veces; el 8,47% fue readmitido 3 veces y el restante 7,31% fue readmitido 4 veces.

# %% [markdown]
# **Gráfico 3: Boxplot de la cantidad de pacientes según la duración de la estadía**

# %% [markdown]
# Para profundizar en el análisis de la duración de la estancia de los pacientes en la clínica, se presenta un boxplot en el cual se podrán visualizar la cantidad de pacientes promedio, los extremos y los outliers que se dan en los tres días que presentan mayor cantidad de pacientes.

# %%
x = CANTIDAD_PACIENTES_ESTADIA.loc[CANTIDAD_PACIENTES_ESTADIA['Cantidad_Pacientes'] >= 14000]
fig, ax = plt.subplots(figsize=(8, 4))
ax.boxplot(x=x.T)
plt.xticks([1,2,3], [1, 3, 4])
ax.set_title('Gráfico 3: Boxplot de la cantidad de pacientes según la duración de la estadía')
ax.set_xlabel('Duración de la Estadía (en días)')
ax.set_ylabel('Cantidad de Pacientes')
# Out:
# Text(0, 0.5, 'Cantidad de Pacientes')

# %% [markdown]
# **Interpretación:**
#
# Este gráfico boxplot complementa al gráfico 1, ya que se puede observar los valores mínimos y máximos de la cantidad de pacientes en función a la duración de su estadía en la clínica. También permite apreciar la media, la mediana y los cuartiles. Además, a partir del mismo se puede determinar que esta variable (duración de la estancia) no presentan valores atípicos en estos casos donde se presentan una mayor cantidad de pacientes, es decir, con una duración de la internación de 1, 3 y 4 días.

# %% [markdown]
# #### **ANÁLISIS DE VARIABLES INDEPENDIENTES**

# %% [markdown]
# **Gráfico 4: Cantidad de pacientes con problemas Psicológicos**

# %%
DES_PSICO = Clinica1.groupby(['desordenPsicologico']).size().reset_index(name='Cantidad')

fig, ax = plt.subplots(figsize=(8,4))
plt.xticks(range(18))
ax.bar(DES_PSICO['desordenPsicologico'], DES_PSICO.Cantidad)
plt.xticks([0,1], ["NO", "SI"])
ax.set_title('Gráfico 4: Cantidad de pacientes con problemas Psicológicos')
ax.set_ylabel('Cantidad de Pacientes')
ax.set_xlabel('Desorden Psicológico')
# Out:
# Text(0.5, 0, 'Desorden Psicológico')

# %% [markdown]
# **Interpretación:**
#
# Al analizar la variable mediante el Gráfico 4 nos damos cuenta de que la cantidad de pacientes que presentan problemas Psicológicos no es elevada con repecto al total. A pesar de ello, esta variable es la segunda que presenta mayor correlación con respecto a la duración de dichos pacientes en la clínica.

# %% [markdown]
# **Gráfico 5: Cantidad de pacientes con desórdenes en sangre**

# %%
DES_SANGRE = Clinica1.groupby(['desordenSangre']).size().reset_index(name='Cantidad')

fig, ax = plt.subplots(figsize=(8,4))
plt.xticks(range(18))
ax.bar(DES_SANGRE['desordenSangre'], DES_SANGRE.Cantidad)
plt.xticks([0,1], ["NO", "SI"])
ax.set_title('Gráfico 5: Cantidad de pacientes con desórdenes en sangre')
ax.set_ylabel('Cantidad de Pacientes')
ax.set_xlabel('Desorden en Sangre')
# Out:
# Text(0.5, 0, 'Desorden en Sangre')

# %% [markdown]
# **Interpretación:**
#
# La cantidad de pacientes que presentan desórdenes en sangre es menor a la que no presentan esta condición.

# %% [markdown]
# **Gráfico 6: Cantidad de pacientes con falta de hierro**

# %%
FALTA_HIERRO = Clinica1.groupby(['faltaHierro']).size().reset_index(name='Cantidad')

fig, ax = plt.subplots(figsize=(8,4))
plt.xticks(range(18))
ax.bar(FALTA_HIERRO['faltaHierro'], FALTA_HIERRO.Cantidad)
plt.xticks([0,1], ["NO", "SI"])
ax.set_title('Gráfico 6: Cantidad de pacientes con falta de hierro')
ax.set_ylabel('Cantidad de Pacientes')
ax.set_xlabel('Falta de Hierro')
# Out:
# Text(0.5, 0, 'Falta de Hierro')

# %% [markdown]
# **Interpretación:**
#
# Al igual que en el caso de las variables analizadas anteriormente, la cantidad de pacientes que presentan una falta de hierro es menor a la que no tiene esta condición.

# %% [markdown]
# **Gráfico 7: Cantidad de pacientes con otros problemas psíquicos**

# %%
PSICO = Clinica1.groupby(['otrosDesordenesPsiquicos']).size().reset_index(name='Cantidad')

fig, ax = plt.subplots(figsize=(8,4))
plt.xticks(range(18))
ax.bar(PSICO['otrosDesordenesPsiquicos'], PSICO.Cantidad)
plt.xticks([0,1], ["NO", "SI"])
ax.set_title('Gráfico 7: Cantidad de pacientes con otros desórdenes psíquicos')
ax.set_ylabel('Cantidad de Pacientes')
ax.set_xlabel('Otros Desórdenes Psíquicos')
# Out:
# Text(0.5, 0, 'Otros Desórdenes Psíquicos')

# %% [markdown]
# **Interpretación:**
#
# Como se puede observar, nuevamente el número de pacientes que presentan otras condiciones psíquicas es menor a los que no tienen trastornos de este tipo.

# %% [markdown]
# # **MODELO DE MACHINE LEARNING**

# %% [markdown]
# ### **ÁRBOLES DE REGRESIÓN**

# %% [markdown]
# 1. Definición de variable Objetivo y variables independientes:

# %%
# ==============================================================================
X = Clinica1.drop(['duracionEstancia'], axis=1)
y = Clinica1['duracionEstancia']

# %% [markdown]
# 2. Verificación de dimensiones:

# %%
# ==============================================================================
print(X.shape)  # Dimensiones de X
print(y.shape) # Dimensiones de y
# Out:
# (95013, 5)
# (95013,)

# %% [markdown]
# 3. División de datos de entrenamiento y de test:

# %%
# ==============================================================================
X_train, X_test, y_train, y_test = train_test_split(
                                        X,
                                        y,
                                        test_size=0.30,
                                        random_state = 0
                                    )

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (66509, 5)
# (28504, 5)
# (66509,)
# (28504,)

# %% [markdown]
# 4. Creación del modelo:

# %%
# ==============================================================================
modelo = DecisionTreeRegressor(max_depth=3)

# %% [markdown]
# 5. Entrenamiento del modelo:

# %%
# ==============================================================================
modelo = modelo.fit(X_train, y_train)

# %% [markdown]
# 6. Visualización del entrenamiento del modelo:

# %%
fig = plt.figure(figsize=(20, 18))

tree.plot_tree(modelo, feature_names= list(X.columns.values),
                        class_names=list(y.values), filled=True)

plt.show()

# %% [markdown]
# 7. Predicciones:

# %%
# ==============================================================================
y_train_pred = modelo.predict(X_train)
y_train_pred
# Out:
# array([2.32742979, 2.32742979, 2.32742979, ..., 2.32742979, 2.32742979,
#        2.32742979])

# %%
# ==============================================================================
y_test_pred = modelo.predict(X_test)
y_test_pred
# Out:
# array([4.10672359, 5.0055018 , 5.0055018 , ..., 2.32742979, 4.10672359,
#        7.25440033])

# %% [markdown]
# 8. Comparativa con las etiquetas reales:

# %%
print('Error en datos de train:', mean_squared_error(y_train_pred,y_train))
print('Error en datos de test:', mean_squared_error(y_test_pred,y_test))
print('Score en datos de train:', modelo.score(X_train, y_train)*100)
print('Score en datos de test:', modelo.score(X_test, y_test)*100)

ad_test_mse = mean_squared_error(y_train, y_train_pred)
ad_train_mse = mean_squared_error(y_test, y_test_pred)
# Out:
# Error en datos de train: 1.8683994688844492
# Error en datos de test: 1.9198880867255896
# Score en datos de train: 60.56590459813288
# Score en datos de test: 59.91710091306215

# %% [markdown]
# 9. Métricas

# %%
#===============================================================================

mse_ad = mean_squared_error(y_test, y_test_pred)
print("MSE:", mse_ad)
#--------------------------------------------------
rmse_ad = np.sqrt(mse_ad)
print("RMSE:", rmse_ad)
#--------------------------------------------------
mae_ad = MAE(y_test, y_test_pred)
print("MAE:", mae_ad)
#--------------------------------------------------
r2_ad = r2_score(y_test, y_test_pred)
print("R^2:", r2_ad)
# Out:
# MSE: 1.9198880867255896
# RMSE: 1.385600262242177
# MAE: 1.0792537704780907
# R^2: 0.5991710091306215

# %% [markdown]
# ### **RANDOM FOREST**

# %% [markdown]
# 1. División de los datos en entrenamiento y test:

# %%
X_train_rf, X_test_rf, y_train_rf, y_test_rf = train_test_split(
                                        Clinica1.drop(columns = "duracionEstancia"),
                                        Clinica1['duracionEstancia'],
                                        random_state = 123
                                    )

# %% [markdown]
# 2. Creación del modelo:

# %%
# ==============================================================================
modelo = RandomForestRegressor(
            n_estimators = 200,
            criterion    = "squared_error",
            max_depth    = 6,
            max_features = 'sqrt',
            oob_score    = True,
            n_jobs       = -1,
            random_state = 123
         )

# %% [markdown]
# 3. Entrenamiento del modelo:

# %%
# ==============================================================================
modelo.fit(X_train_rf, y_train_rf)
# Out:
# RandomForestRegressor(max_depth=6, max_features='sqrt', n_estimators=200,
#                       n_jobs=-1, oob_score=True, random_state=123)

# %% [markdown]
# 4. Predicciones:

# %%
# ==============================================================================
rf_predic_y_train = modelo.predict(X_train_rf)
rf_predic_y_test  = modelo.predict(X_test_rf)

# %% [markdown]
# 5. Error de test del modelo inicial:

# %%
# ==============================================================================

print('Error en datos de train:', mean_squared_error(rf_predic_y_train, y_train_rf))
print('Error en datos de test:', mean_squared_error(rf_predic_y_test,y_test_rf))
print('Score en datos de train:', modelo.score(X_train_rf, y_train_rf)*100)
print('Score en datos de test:', modelo.score(X_test_rf, y_test_rf)*100)

rfr_test_mse = mean_squared_error(y_train_rf, rf_predic_y_train)
rfr_train_mse = mean_squared_error(y_test_rf, rf_predic_y_test)
# Out:
# Error en datos de train: 1.46330075086708
# Error en datos de test: 1.452761943794513
# Score en datos de train: 69.28031135190476
# Score en datos de test: 69.2459473825283

# %% [markdown]
# 6. Métricas

# %%
#===============================================================================

mse_rf = mean_squared_error(y_test_rf, rf_predic_y_test)
print("MSE:", mse_rf)
#--------------------------------------------------
rmse_rf = np.sqrt(mse_rf)
print("RMSE:", rmse_rf)
#--------------------------------------------------
mae_rf = MAE(y_test_rf, rf_predic_y_test)
print("MAE:", mae_rf)
#--------------------------------------------------
r2_rf = r2_score(y_test_rf, rf_predic_y_test)
print("R^2:", r2_rf)
# Out:
# MSE: 1.452761943794513
# RMSE: 1.205305747017956
# MAE: 0.9250887837341353
# R^2: 0.6924594738252831

# %% [markdown]
# ### **KNeighbors Regression**

# %% [markdown]
# 1. Datos de Entrada:

# %%
# ==============================================================================
X_knn = Clinica1.drop(['duracionEstancia'], axis=1)
y_knn = Clinica1['duracionEstancia']

# %% [markdown]
# 2. Verificación de las dimensiones:

# %%
# =============================================================================
print(X_knn.shape)  # Dimensiones de X
print(y_knn.shape)  # Dimensiones de y
# Out:
# (95013, 5)
# (95013,)

# %% [markdown]
# 3. División en datos de entrenamiento y test:

# %%
# ==============================================================================
X_train_knn, X_test_knn, y_train_knn, y_test_knn = train_test_split(  X_knn, #X_pca
                                                      y_knn,
                                                      test_size=0.30,
                                                      random_state=0,
                                                      stratify=y)

# %% [markdown]
# 4. Creación y ajuste del modelo de KNeighborsRegressor

# %%
# ==============================================================================
modelo = KNeighborsRegressor(n_neighbors=3)
modelo.fit(X_train_knn, y_train_knn)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %% [markdown]
# 5. Realización de predicciones:

# %%
# ==============================================================================
predic_y_train_knn = modelo.predict(X_train_knn)
predic_y_test_knn = modelo.predict(X_test_knn)

# %% [markdown]
# 6. Visualización de resultados:

# %% [markdown]
# Número de readmisiones:

# %%
# ==============================================================================
plt.figure(figsize=(10, 8))
sns.set_theme()

# Datos de entrenamiento

plt.scatter(X_train_knn['numReadmisiones'], y_train_knn, color='green', alpha=0.2, label='Datos Train')
plt.scatter(X_train_knn['numReadmisiones'], predic_y_train_knn, color='black', linewidth=1.0, linestyle='--', label='Predicción Train')

# Datos de prueba

plt.scatter(X_test_knn['numReadmisiones'], y_test_knn, color='red', linewidth=1.0, alpha=0.2, label='Datos Test')
plt.scatter(X_test_knn['numReadmisiones'], predic_y_test_knn, color='blue', linewidth=1.0, label='Predicción Test')

plt.xlabel("Longitud de Rama Horizontal (LRH)")
plt.ylabel("Duración Estancia de los Pacientes")
plt.title("Predicción Duración Estancia de los Pacientes en base al Número de Readmisiones")

plt.legend()
plt.show()

# %% [markdown]
# Falta de Hierro

# %%
# ==============================================================================
plt.figure(figsize=(10, 8))
sns.set_theme()

# Datos de entrenamiento

plt.scatter(X_train_knn['faltaHierro'], y_train_knn, color='green', alpha=0.2, label='Datos Train')
plt.scatter(X_train_knn['faltaHierro'], predic_y_train_knn, color='black', linewidth=1.0, linestyle='--', label='Predicción Train')

# Datos de prueba

plt.scatter(X_test_knn['faltaHierro'], y_test_knn, color='red', linewidth=1.0, alpha=0.2, label='Datos Test')
plt.scatter(X_test_knn['faltaHierro'], predic_y_test_knn, color='blue', linewidth=1.0, label='Predicción Test')

plt.xlabel("Longitud de Rama Horizontal (LRH)")
plt.ylabel("Duración Estancia de los Pacientes")
plt.title("Predicción Duración Estancia de los Pacientes en base a la Falta de Hierro")

plt.legend()
plt.show()

# %% [markdown]
# Desorden Psicológico:

# %%
# ==============================================================================
plt.figure(figsize=(10, 8))
sns.set_theme()

# Datos de entrenamiento

plt.scatter(X_train_knn['desordenPsicologico'], y_train_knn, color='green', alpha=0.2, label='Datos Train')
plt.scatter(X_train_knn['desordenPsicologico'], predic_y_train_knn, color='black', linewidth=1.0, linestyle='--', label='Predicción Train')

# Datos de prueba

plt.scatter(X_test_knn['desordenPsicologico'], y_test_knn, color='red', linewidth=1.0, alpha=0.2, label='Datos Test')
plt.scatter(X_test_knn['desordenPsicologico'], predic_y_test_knn, color='blue', linewidth=1.0, label='Predicción Test')

plt.xlabel("Longitud de Rama Horizontal (LRH)")
plt.ylabel("Duración Estancia de los Pacientes")
plt.title("Predicción Duración Estancia de los Pacientes en base al Desorden Psicológico")

plt.legend()
plt.show()

# %% [markdown]
# Otros desórdenes Psíquicos

# %%
# ==============================================================================
plt.figure(figsize=(10, 8))
sns.set_theme()

# Datos de entrenamiento

plt.scatter(X_train_knn['otrosDesordenesPsiquicos'], y_train_knn, color='green', alpha=0.2, label='Datos Train')
plt.scatter(X_train_knn['otrosDesordenesPsiquicos'], predic_y_train_knn, color='black', linewidth=1.0, linestyle='--', label='Predicción Train')

# Datos de prueba

plt.scatter(X_test_knn['otrosDesordenesPsiquicos'], y_test_knn, color='red', linewidth=1.0, alpha=0.2, label='Datos Test')
plt.scatter(X_test_knn['otrosDesordenesPsiquicos'], predic_y_test_knn, color='blue', linewidth=1.0, label='Predicción Test')

plt.xlabel("Longitud de Rama Horizontal (LRH)")
plt.ylabel("Duración Estancia de los Pacientes")
plt.title("Predicción Duración Estancia de los Pacientes en base a Otros desórdenes Psíquicos")

plt.legend()
plt.show()

# %% [markdown]
# Desorden en Sangre

# %%
# ==============================================================================
plt.figure(figsize=(10, 8))
sns.set_theme()

# Datos de entrenamiento

plt.scatter(X_train_knn['desordenSangre'], y_train_knn, color='green', alpha=0.2, label='Datos Train')
plt.scatter(X_train_knn['desordenSangre'], predic_y_train_knn, color='black', linewidth=1.0, linestyle='--', label='Predicción Train')

# Datos de prueba

plt.scatter(X_test_knn['desordenSangre'], y_test_knn, color='red', linewidth=1.0, alpha=0.2, label='Datos Test')
plt.scatter(X_test_knn['desordenSangre'], predic_y_test_knn, color='blue', linewidth=1.0, label='Predicción Test')

plt.xlabel("Longitud de Rama Horizontal (LRH)")
plt.ylabel("Duración Estancia de los Pacientes")
plt.title("Predicción Duración Estancia de los Pacientes en base a Desorden en Sangre")

plt.legend()
plt.show()

# %% [markdown]
# 7. Métricas knn:

# %%
#===============================================================================

mse_knn = mean_squared_error(y_test_knn, predic_y_test_knn)
print("MSE:", mse_knn)
#--------------------------------------------------
rmse_knn = np.sqrt(mse_knn)
print("RMSE:", rmse_knn)
#--------------------------------------------------
mae_knn = MAE(y_test_knn, predic_y_test_knn)
print("MAE:", mae_knn)
#--------------------------------------------------
r2_knn = r2_score(y_test_knn, predic_y_test_knn)
print("R^2:", r2_knn)
# Out:
# MSE: 2.358557863223875
# RMSE: 1.535759702304978
# MAE: 1.220050986995977
# R^2: 0.5032602677446598

# %%
# ==============================================================================

print('Error en datos de train:', mean_squared_error(predic_y_train_knn, y_train_knn))
print('Error en datos de test:', mean_squared_error(predic_y_test_knn,y_test_knn))
print('Score en datos de train:', modelo.score(X_train_knn, y_train_knn)*100)
print('Score en datos de test:', modelo.score(X_test_knn, y_test_knn)*100)

knn_test_mse = mean_squared_error(y_train_knn, predic_y_train_knn)
knn_train_mse = mean_squared_error(y_test_knn, predic_y_test_knn)
# Out:
# Error en datos de train: 2.3375232424684373
# Error en datos de test: 2.358557863223875
# Score en datos de train: 69.30873084670355
# Score en datos de test: 69.39207556735951

# %% [markdown]
# ## **XG-Boost Regression**

# %% [markdown]
# 1. Datos de entrada:

# %%
# ==============================================================================
X_xgb = Clinica1.drop(['duracionEstancia'], axis=1)
y_xgb = Clinica1['duracionEstancia']

# %% [markdown]
# 2. División en datos de entrenamiento y test:

# %%
# ==============================================================================
X_train_xgb, X_test_xgb, y_train_xgb, y_test_xgb = train_test_split(X_xgb,
                                                    y_xgb,
                                                    test_size=0.30,
                                                    random_state=0,
                                                    stratify=y
                                                    )

# %% [markdown]
# 3. Creación del modelo:

# %%
# ==============================================================================
modelo = xgb.XGBRegressor(n_estimators=100, random_state=42)

# %% [markdown]
# 4. Entrenamiento del modelo:

# %%
# ==============================================================================
modelo.fit(X_train_xgb, y_train_xgb)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=42, ...)

# %% [markdown]
# 5. Predicciones:

# %%
# ==============================================================================
predic_y_train_xgb = modelo.predict(X_train_xgb)
predic_y_test_xgb  = modelo.predict(X_test_xgb)

# %% [markdown]
# 6. Visualización de resultados:

# %% [markdown]
# Número de Readmisiones:

# %%
# ==============================================================================
plt.figure(figsize = (10,8))
sns.set_theme()

# Datos de entrenamiento
plt.scatter(X_train_xgb['numReadmisiones'], y_train_xgb, color='green', alpha=0.1, label='Datos Train')
plt.scatter(X_train_xgb['numReadmisiones'], predic_y_train_xgb, color='black', linewidth=1.5, label='Predicción Train')

# Datos de prueba
plt.scatter(X_test_xgb['numReadmisiones'], y_test_xgb, color='red', alpha=0.1, label='Datos Test')
plt.scatter(X_test_xgb['numReadmisiones'], predic_y_test_xgb, color='blue', linewidth=1.5, label='Predicción Test')

plt.xlabel("Longitud de Rama Horizontal (LRH)")
plt.ylabel("Duración Estancia de los Pacientes")
plt.title("Predicción Duración Estancia de los Pacientes en base al Número de Readmisiones")



plt.legend()
plt.show()

# %% [markdown]
# Falta de Hierro:

# %%
# ==============================================================================
plt.figure(figsize = (10,8))
sns.set_theme()

# Datos de entrenamiento
plt.scatter(X_train_xgb['faltaHierro'], y_train_xgb, color='green', alpha=0.1, label='Datos Train')
plt.scatter(X_train_xgb['faltaHierro'], predic_y_train_xgb, color='black', linewidth=1.5, label='Predicción Train')

# Datos de prueba
plt.scatter(X_test_xgb['faltaHierro'], y_test_xgb, color='red', alpha=0.1, label='Datos Test')
plt.scatter(X_test_xgb['faltaHierro'], predic_y_test_xgb, color='blue', linewidth=1.5, label='Predicción Test')

plt.xlabel("Longitud de Rama Horizontal (LRH)")
plt.ylabel("Duración Estancia de los Pacientes")
plt.title("Predicción Duración Estancia de los Pacientes en base a la Falta de Hierro")



plt.legend()
plt.show()

# %% [markdown]
# Desorden Psicológico:

# %%
# ==============================================================================
plt.figure(figsize = (10,8))
sns.set_theme()

# Datos de entrenamiento
plt.scatter(X_train_xgb['desordenPsicologico'], y_train_xgb, color='green', alpha=0.1, label='Datos Train')
plt.scatter(X_train_xgb['desordenPsicologico'], predic_y_train_xgb, color='black', linewidth=1.5, label='Predicción Train')

# Datos de prueba
plt.scatter(X_test_xgb['desordenPsicologico'], y_test_xgb, color='red', alpha=0.1, label='Datos Test')
plt.scatter(X_test_xgb['desordenPsicologico'], predic_y_test_xgb, color='blue', linewidth=1.5, label='Predicción Test')

plt.xlabel("Longitud de Rama Horizontal (LRH)")
plt.ylabel("Duración Estancia de los Pacientes")
plt.title("Predicción Duración Estancia de los Pacientes en base a Desorden Psicológico")



plt.legend()
plt.show()

# %% [markdown]
# Otros desórdenes Psíquicos:

# %%
# ==============================================================================
plt.figure(figsize = (10,8))
sns.set_theme()

# Datos de entrenamiento
plt.scatter(X_train_xgb['otrosDesordenesPsiquicos'], y_train_xgb, color='green', alpha=0.1, label='Datos Train')
plt.scatter(X_train_xgb['otrosDesordenesPsiquicos'], predic_y_train_xgb, color='black', linewidth=1.5, label='Predicción Train')

# Datos de prueba
plt.scatter(X_test_xgb['otrosDesordenesPsiquicos'], y_test_xgb, color='red', alpha=0.1, label='Datos Test')
plt.scatter(X_test_xgb['otrosDesordenesPsiquicos'], predic_y_test_xgb, color='blue', linewidth=1.5, label='Predicción Test')

plt.xlabel("Longitud de Rama Horizontal (LRH)")
plt.ylabel("Duración Estancia de los Pacientes")
plt.title("Predicción Duración Estancia de los Pacientes en base a Otros Desórdenes Psíquicos")



plt.legend()
plt.show()

# %% [markdown]
# Desorden en Sangre:

# %%
# ==============================================================================
plt.figure(figsize = (10,8))
sns.set_theme()

# Datos de entrenamiento
plt.scatter(X_train_xgb['desordenSangre'], y_train_xgb, color='green', alpha=0.1, label='Datos Train')
plt.scatter(X_train_xgb['desordenSangre'], predic_y_train_xgb, color='black', linewidth=1.5, label='Predicción Train')

# Datos de prueba
plt.scatter(X_test_xgb['desordenSangre'], y_test_xgb, color='red', alpha=0.1, label='Datos Test')
plt.scatter(X_test_xgb['desordenSangre'], predic_y_test_xgb, color='blue', linewidth=1.5, label='Predicción Test')

plt.xlabel("Longitud de Rama Horizontal (LRH)")
plt.ylabel("Duración Estancia de los Pacientes")
plt.title("Predicción Duración Estancia de los Pacientes en base al Desorden en Sangre")



plt.legend()
plt.show()

# %% [markdown]
# 7. Métricas XGB:

# %%
# ==============================================================================
mse_xgb = mean_squared_error(y_test_xgb, predic_y_test_xgb)
print("MSE:", mse_xgb)
#--------------------------------------------------
rmse_xgb = np.sqrt(mse_xgb)
print("RMSE:", rmse_xgb)
#--------------------------------------------------
mae_xgb = MAE(y_test_xgb, predic_y_test_xgb)
print("MAE:", mae_xgb)
#--------------------------------------------------
r2_xgb = r2_score(y_test_xgb, predic_y_test_xgb)
print("R^2:", r2_xgb)
# Out:
# MSE: 1.4532874292096718
# RMSE: 1.20552371573921
# MAE: 0.929299317156034
# R^2: 0.6939207556735951

# %%
# ==============================================================================
# ==============================================================================

print('Error en datos de train:', mean_squared_error(y_train_xgb, predic_y_train_xgb))
print('Error en datos de test:', mean_squared_error(y_test_xgb, predic_y_test_xgb))
print('Score en datos de train:', modelo.score(X_train_xgb, y_train_xgb)*100)
print('Score en datos de test:', modelo.score(X_test_xgb, y_test_xgb)*100)


xgb_test_mse = mean_squared_error(y_train_xgb, predic_y_train_xgb)
xgb_train_mse = mean_squared_error(y_test_xgb, predic_y_test_xgb)
# Out:
# Error en datos de train: 1.4596540495198256
# Error en datos de test: 1.4532874292096718
# Score en datos de train: 69.30873084670355
# Score en datos de test: 69.39207556735951

# %% [markdown]
# ## **COMPARACIÓN DE LOS MODELOS**

# %% [markdown]
# Para poder determinar el mejor modelo, se opta por mostrar los errores medios obtenidos en cada modelo utilizado, para de esta manera poder tomar una decisión.

# %%
valores = [knn_train_mse, rfr_train_mse, xgb_train_mse]

nombres = ['Kns', 'Forest', 'XGB']

plt.figure(figsize=(10, 6))
plt.bar(nombres, valores, color='blue')

plt.xlabel('Modelos')
plt.ylabel('MSE Train')
plt.title('Comparación de MSE entre modelos')

for i, value in enumerate(valores):
    plt.text(i, value, str(round(value, 2)), ha='center', va='bottom')

plt.show()

# %% [markdown]
# A partir de los resultados arrojados por los distintos modelos utilizados y basándonos en el error cuádratico medio (MSE) los modelos que Forest y XGB presentan el mismo error y a su vez es el menor, ya que KNS presenta un error mayor. De esta manera, los dos modelos que presentan mejor precisión son Forest y XGB.

# %% [markdown]
# ## **HIPERPARÁMETROS**

# %% [markdown]
# 1. Cantidad óptima de clústers seleccionada:

# %%
cv = 6

# %% [markdown]
# 2. Función de pérdida a optimizar

# %%
loss = ["ls", "lad", "huber"]

# %% [markdown]
# 4. Profundidad máxima de cada árbol

# %%
max_depth = [2, 3, 5, 10, 15]

# %% [markdown]
# 5. Número mínimo de muestras por hoja:

# %%
min_samples_leaf = [1, 2, 4, 6, 8]

# %% [markdown]
# 6. Número mínimo de muestras para dividir un nodo

# %%
min_samples_split = [1, 2, 4, 6, 10]

# %% [markdown]
# 7. Número máximo de características a considerar para hacer divisiones

# %%
# ==============================================================================
max_features = ["auto", "sqrt", "log2", None]

hyperparameter_grid = {"loss": loss,
                       "max_depth": max_depth,
                       "min_samples_leaf": min_samples_leaf,
                       "min_samples_split": min_samples_split,
                       "max_features": max_features}

trees_grid = {"n_estimators": [50, 100, 150, 200, 250, 300]}

# %% [markdown]
# **Random Forest:**

# %%
# ==============================================================================

n_estimators = [50,100,250,300]

hyperparameters = dict(n_estimators=n_estimators)

random_forest_model = RandomForestRegressor(random_state=60)

rf_grid_search = GridSearchCV(estimator=random_forest_model, param_grid=hyperparameters, cv=cv,
                           scoring="neg_mean_absolute_error", verbose=1,
                           n_jobs=-1, return_train_score=True)

rf_grid_search.fit(X_train, y_train)

rf_final_model = rf_grid_search.best_estimator_

print("\n Rendimiento del modelo de bosque aleatorio en el conjunto de prueba: R2 = {:.04f}".format(r2_score(y_test,rf_final_model.predict(X_test))))
# Out:
# Fitting 6 folds for each of 4 candidates, totalling 24 fits
#
#  Rendimiento del modelo de bosque aleatorio en el conjunto de prueba: R2 = 0.6897

# %% [markdown]
# **K-nearest Neighbour**

# %%
leaf_size = [1, 5]
n_neighbors = [1, 5]


hyperparameters = dict(leaf_size=leaf_size,
                       n_neighbors=n_neighbors,
                       p=[1, 2])


knn_model = KNeighborsRegressor(n_neighbors=6)

knn_grid_search = GridSearchCV(estimator=knn_model,
                              param_grid=hyperparameters,
                              cv=5,
                              scoring="neg_mean_absolute_error",
                              verbose=1,
                              n_jobs=-1,
                               return_train_score=True)

knn_grid_search.fit(X_train, y_train)

knn_final_model = knn_grid_search.best_estimator_

print("\n Rendimiento del modelo K-Neighbors en el conjunto de prueba: R2 = {:.04f}".format(r2_score(y_test,knn_final_model.predict(X_test))))
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
#
#  Rendimiento del modelo K-Neighbors en el conjunto de prueba: R2 = 0.6551

# %% [markdown]
# Entre los dos modelos evaluados, el Ramdom Forest obtuvo un mejor rendimiento en comparación con el K-nearest Neighbour, siendo que el primero obtuvo un r2 de 0.69 y el KNN un r2 de 0.66.

# %% [markdown]
# ## **CROSS VALIDATION**

# %% [markdown]
# ### **Cross Validation Loocv**

# %%
cv = LeaveOneOut()
val_mae = make_scorer(MAE)

model = xgb.XGBRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

print('Error en datos de train:', mean_squared_error(y_train, y_train_pred))
print('Error en datos de test:', mean_squared_error(y_test, y_test_pred))

scores = cross_val_score(model, X.head(100), y.head(100), scoring=val_mae, cv=cv, verbose=0)
precision = r2_score(y_test, y_test_pred)

print("Scores", scores)
print('Precisión:', precision)
# Out:
# Error en datos de train: 1.4594565662257233
# Error en datos de test: 1.4490485398465018
# Scores [1.20678174 0.62488937 0.86218214 0.16637969 0.49998808 0.3999548
#  1.00030708 1.20678174 0.17230022 0.86218214 0.80000925 1.20678174
#  0.66642475 1.68737173 0.43754792 0.49998808 0.86218214 3.27574539
#  0.17230022 1.20678174 0.86218214 0.49998808 0.99910975 1.99962664
#  1.41117239 0.98544359 0.66667747 0.3999548  0.17230022 0.43754792
#  1.00030708 0.86218214 0.27239895 0.818542   0.62488937 0.17230022
#  0.16637969 0.80000925 0.86218214 1.00055695 0.17230022 0.818542
#  0.81545591 0.86218214 0.62488937 0.62488937 0.86218214 2.56258273
#  1.68737173 1.33307838 0.86218214 1.20678174 0.66681862 0.86218214
#  0.818542   0.66667747 0.86218214 1.33307838 1.7961936  0.17230022
#  0.3999548  0.17230022 0.62488937 1.68737173 2.12551141 0.27239895
#  2.00026941 2.50036621 0.818542   1.68737173 0.35035515 0.43754792
#  0.43754792 3.52069998 1.99974918 1.16522694 0.818542   1.00030708
# ...

# %% [markdown]
# **Interpretación**
#
# Un MSE de entrenamiento de 1,459 significa que, en promedio, las predicciones del modelo difieren de los valores reales en una cantidad de 1,459 (al cuadrado).
# En cuanto al MSE de pruebas, las predicciones del modelo difieren de los valores reales en una cantidad de 1,449 (al cuadrado).
# La precisión se mide utilizando el coeficiente de determinación R^2, que es una medida que indica cuánta varianza en los datos de prueba es explicada por el modelo, la cual arroja un valor de 0,693, señalando que existe un ajuste aceptable del modelo respecto a los datos de prueba.

# %% [markdown]
# # **CONCLUSIÓN**

# %% [markdown]
# En base a las métricas obtenidas a partir del entrenamiento de los algoritmos utilizados para analizar la duración de la estancia de los pacientes en la clínica, se pudo establecer que el que **mejor rendimiento** presenta es el de **XGB**, esto se debe a que el valor obtenido de **r2** es de **0,69**.
#
# Al aplicar hiperparámetros, los algoritmos de Random Forest y de Knn se vieron afectados. En el caso del primer algoritmo, este redujo su valor de r2 de 0,69 a 0,68. En el caso de Knn, tuvo una mejora, ya que pasó de 0,50 a 0,65, pero esto a costa de una mayor costo, medido por el tiempo de ejecución.
#
# Algunas conclusiones a las que se pudo arribar en base al análisis de los datos son las siguientes:
# *   En valores absolutos, la duración de la estancia de los
# pacientes en la clínica es de 1, 3 y 4 días, ya que son los que presentan valores que superan las 14 mil pacientes que permanecen esa cantidad de tiempo, cada una.
# *   La variable que tiene una correlación más alta respecto a la duración de la estancia del paciente en la clínica corresponde al **Número de Readmisiones**. Teniendo en cuenta las variables vinculadas con patologías, la variable de mayor correlación es la de **Desorden Psicológico**.
# *  Puede notarse que en el caso de las varibles binarias (SI/NO) que tienen una mayor correlación con la variable objetivo, en todos los casos son más los pacientes que no tienen esa patología, pero aún así dichas variables tienen un peso en la duración de la estancia del paciente en la clínica.
#
# En cuanto a la hipótesis planteada, la misma se refuta dado que se determinó que la variable que tiene mayor incidencia (después que el número de readmisiones) en lo que respecta a la duración de la estancia del paciente en la clínica se vincula con patologías mentales.
#
#
# **Recomendaciones**
# *   Llevar adelante un seguimiento de los pacientes luego de su primera vez internado en la clínica, recabando datos para conformar un historial clínico que permita entender mejor los motivos de su regreso en caso de que sucede; además, de poder tomar medidas que reduzcan su permanencia en la clínica.
# *   Analizar cuáles son los elementos necesarios para brindar un servicio de internación a los pacientes con desórdenes psicológicos, para poder de esta manera reasignar recursos de la clínica.
# *  Acondicionar los espacios para recibir a pacientes con problemas psicológicos.
# *   Agilizar los procesos de análisis de sangre, para lograr reducir el tiempo en el cual se tiene los estudios y de esta manera realizar un rápido diagnóstico.
